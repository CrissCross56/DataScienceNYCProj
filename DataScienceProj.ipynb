# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'https://data.cityofnewyork.us/api/v3/views/h9gi-nx95/query.json?$limit=50000'
df = pd.read_json(url)
df
# Out:
#                         :id           :version  \
# 0        row-rsc3.wgwr-zpi9  rv-qukg_54rg~e45q
# 1        row-t9dc~q8a7~jwk4  rv-vmia.j6tc.thwm
# 2        row-h8ny_qxbv_ezwp  rv-x4h8~yx6x.vdk4
# 3        row-gxrs-hm78-w9gs  rv-fazg.rwsa.9gjd
# 4        row-58i4.zk9q.sxqs  rv-4bks~69au~m7kz
# ...                     ...                ...
# 2269182  row-2eq4~ggkm~mmj5  rv-kufg_3vu2~z4xi
# 2269183  row-xdtm_dzxq-amyj  rv-bbrh~kh8d~c8x4
# 2269184  row-dfe5_g8eg.ht6q  rv-h9dt-t256.24by
# 2269185  row-t2hp~3vkd~byaj  rv-zhbd.zrq5-thkz
# 2269186  row-imm7-hm8u_mr2s  rv-h7tw~cv8d.h8w8
#
#                              :created_at                      :updated_at  \
# 0       2021-09-14 22:52:22.882000+00:00 2021-09-14 22:52:26.672000+00:00
# 1       2022-03-29 22:52:48.720000+00:00 2022-03-29 22:52:49.994000+00:00
# 2       2023-11-06 23:52:10.201000+00:00 2023-11-06 23:52:18.104000+00:00
# 3       2022-07-04 22:51:56.069000+00:00 2022-07-04 22:52:04.895000+00:00
# 4       2022-09-26 22:52:05.596000+00:00 2022-09-26 22:52:11.092000+00:00
# ...                                  ...                              ...
# 2269182 2021-04-19 13:31:42.037000+00:00 2021-04-19 13:32:13.860000+00:00
# 2269183 2021-04-19 13:31:42.037000+00:00 2021-04-19 13:32:13.860000+00:00
# 2269184 2021-04-19 13:31:42.037000+00:00 2021-04-19 13:32:13.860000+00:00
# 2269185 2021-04-19 13:31:42.037000+00:00 2021-04-19 13:32:13.860000+00:00
# 2269186 2021-04-19 13:31:42.037000+00:00 2021-04-19 13:32:13.860000+00:00
#
#                       crash_date          crash_time  \
# 0        2021-09-11T00:00:00.000 2026-07-14 02:39:00
# 1        2022-03-26T00:00:00.000 2026-07-14 11:45:00
# 2        2023-11-01T00:00:00.000 2026-07-14 01:29:00
# 3        2022-06-29T00:00:00.000 2026-07-14 06:55:00
# 4        2022-09-21T00:00:00.000 2026-07-14 13:21:00
# ...                          ...                 ...
# 2269182  2013-03-15T00:00:00.000 2026-07-14 14:34:00
# 2269183  2013-03-15T00:00:00.000 2026-07-14 12:10:00
# 2269184  2013-03-07T00:00:00.000 2026-07-14 17:00:00
# 2269185  2013-02-18T00:00:00.000 2026-07-14 15:15:00
# 2269186  2013-03-07T00:00:00.000 2026-07-14 21:15:00
#
#                            on_street_name                   off_street_name  \
# 0                   WHITESTONE EXPRESSWAY                         20 AVENUE
# 1                 QUEENSBORO BRIDGE UPPER                               NaN
# 2                           OCEAN PARKWAY                          AVENUE K
# 3                      THROGS NECK BRIDGE                               NaN
# 4                         BROOKLYN BRIDGE                               NaN
# ...                                   ...                               ...
# 2269182  AVENUE L                          OCEAN AVENUE
# 2269183  JAMAICA AVENUE                    218 STREET
# 2269184  2 AVENUE                          EAST 61 STREET
# 2269185  8 AVENUE                          WEST 34 STREET
# 2269186  WEST 46 STREET                    9 AVENUE
#
#          number_of_persons_injured  number_of_persons_killed  ...   latitude  \
# 0                              2.0                       0.0  ...        NaN
# 1                              1.0                       0.0  ...        NaN
# 2                              1.0                       0.0  ...  40.621790
# 3                              0.0                       0.0  ...        NaN
# 4                              0.0                       0.0  ...        NaN
# ...                            ...                       ...  ...        ...
# 2269182                        0.0                       0.0  ...  40.620949
# 2269183                        0.0                       0.0  ...        NaN
# 2269184                        0.0                       0.0  ...  40.761857
# 2269185                        0.0                       0.0  ...  40.752190
# 2269186                        2.0                       0.0  ...  40.760993
#
#          longitude                                           location  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2       -73.970024  {'latitude': 40.62179, 'longitude': -73.970024...
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# ...            ...                                                ...
# 2269182 -73.955491  {'latitude': 40.620949, 'longitude': -73.9554915}
# 2269183        NaN                                                NaN
# 2269184 -73.963425  {'latitude': 40.7618573, 'longitude': -73.9634...
# 2269185 -73.993464  {'latitude': 40.7521904, 'longitude': -73.9934...
# 2269186 -73.990759  {'latitude': 40.7609926, 'longitude': -73.990759}
#
#          contributing_factor_vehicle_3  vehicle_type_code_3  \
# 0                                  NaN                  NaN
# 1                                  NaN                  NaN
# 2                          Unspecified                Sedan
# 3                                  NaN                  NaN
# 4                                  NaN                  NaN
# ...                                ...                  ...
# 2269182                            NaN                  NaN
# 2269183                            NaN                  NaN
# 2269184                            NaN                  NaN
# 2269185                            NaN                  NaN
# 2269186                            NaN                  NaN
#
#          cross_street_name contributing_factor_vehicle_4 vehicle_type_code_4  \
# 0                      NaN                           NaN                 NaN
# 1                      NaN                           NaN                 NaN
# 2                      NaN                           NaN                 NaN
# 3                      NaN                           NaN                 NaN
# 4                      NaN                           NaN                 NaN
# ...                    ...                           ...                 ...
# 2269182                NaN                           NaN                 NaN
# 2269183                NaN                           NaN                 NaN
# 2269184                NaN                           NaN                 NaN
# 2269185                NaN                           NaN                 NaN
# 2269186                NaN                           NaN                 NaN
#
#          contributing_factor_vehicle_5 vehicle_type_code_5
# 0                                  NaN                 NaN
# 1                                  NaN                 NaN
# 2                                  NaN                 NaN
# 3                                  NaN                 NaN
# 4                                  NaN                 NaN
# ...                                ...                 ...
# 2269182                            NaN                 NaN
# 2269183                            NaN                 NaN
# 2269184                            NaN                 NaN
# 2269185                            NaN                 NaN
# 2269186                            NaN                 NaN
#
# [2269187 rows x 33 columns]

# %%
# df = pd.read_json(url)

# %%
# !curl 'https://data.cityofnewyork.us/api/v3/views/h9gi-nx95/query.csv?accessType=DOWNLOAD' -o collision.csv

# %%
# raw_data = pd.read_csv("collision.csv")

# %%
df
# Out:
#                         :id           :version  \
# 0        row-rsc3.wgwr-zpi9  rv-qukg_54rg~e45q
# 1        row-t9dc~q8a7~jwk4  rv-vmia.j6tc.thwm
# 2        row-h8ny_qxbv_ezwp  rv-x4h8~yx6x.vdk4
# 3        row-gxrs-hm78-w9gs  rv-fazg.rwsa.9gjd
# 4        row-58i4.zk9q.sxqs  rv-4bks~69au~m7kz
# ...                     ...                ...
# 2269182  row-2eq4~ggkm~mmj5  rv-kufg_3vu2~z4xi
# 2269183  row-xdtm_dzxq-amyj  rv-bbrh~kh8d~c8x4
# 2269184  row-dfe5_g8eg.ht6q  rv-h9dt-t256.24by
# 2269185  row-t2hp~3vkd~byaj  rv-zhbd.zrq5-thkz
# 2269186  row-imm7-hm8u_mr2s  rv-h7tw~cv8d.h8w8
#
#                              :created_at                      :updated_at  \
# 0       2021-09-14 22:52:22.882000+00:00 2021-09-14 22:52:26.672000+00:00
# 1       2022-03-29 22:52:48.720000+00:00 2022-03-29 22:52:49.994000+00:00
# 2       2023-11-06 23:52:10.201000+00:00 2023-11-06 23:52:18.104000+00:00
# 3       2022-07-04 22:51:56.069000+00:00 2022-07-04 22:52:04.895000+00:00
# 4       2022-09-26 22:52:05.596000+00:00 2022-09-26 22:52:11.092000+00:00
# ...                                  ...                              ...
# 2269182 2021-04-19 13:31:42.037000+00:00 2021-04-19 13:32:13.860000+00:00
# 2269183 2021-04-19 13:31:42.037000+00:00 2021-04-19 13:32:13.860000+00:00
# 2269184 2021-04-19 13:31:42.037000+00:00 2021-04-19 13:32:13.860000+00:00
# 2269185 2021-04-19 13:31:42.037000+00:00 2021-04-19 13:32:13.860000+00:00
# 2269186 2021-04-19 13:31:42.037000+00:00 2021-04-19 13:32:13.860000+00:00
#
#                       crash_date          crash_time  \
# 0        2021-09-11T00:00:00.000 2026-07-14 02:39:00
# 1        2022-03-26T00:00:00.000 2026-07-14 11:45:00
# 2        2023-11-01T00:00:00.000 2026-07-14 01:29:00
# 3        2022-06-29T00:00:00.000 2026-07-14 06:55:00
# 4        2022-09-21T00:00:00.000 2026-07-14 13:21:00
# ...                          ...                 ...
# 2269182  2013-03-15T00:00:00.000 2026-07-14 14:34:00
# 2269183  2013-03-15T00:00:00.000 2026-07-14 12:10:00
# 2269184  2013-03-07T00:00:00.000 2026-07-14 17:00:00
# 2269185  2013-02-18T00:00:00.000 2026-07-14 15:15:00
# 2269186  2013-03-07T00:00:00.000 2026-07-14 21:15:00
#
#                            on_street_name                   off_street_name  \
# 0                   WHITESTONE EXPRESSWAY                         20 AVENUE
# 1                 QUEENSBORO BRIDGE UPPER                               NaN
# 2                           OCEAN PARKWAY                          AVENUE K
# 3                      THROGS NECK BRIDGE                               NaN
# 4                         BROOKLYN BRIDGE                               NaN
# ...                                   ...                               ...
# 2269182  AVENUE L                          OCEAN AVENUE
# 2269183  JAMAICA AVENUE                    218 STREET
# 2269184  2 AVENUE                          EAST 61 STREET
# 2269185  8 AVENUE                          WEST 34 STREET
# 2269186  WEST 46 STREET                    9 AVENUE
#
#          number_of_persons_injured  number_of_persons_killed  ...   latitude  \
# 0                              2.0                       0.0  ...        NaN
# 1                              1.0                       0.0  ...        NaN
# 2                              1.0                       0.0  ...  40.621790
# 3                              0.0                       0.0  ...        NaN
# 4                              0.0                       0.0  ...        NaN
# ...                            ...                       ...  ...        ...
# 2269182                        0.0                       0.0  ...  40.620949
# 2269183                        0.0                       0.0  ...        NaN
# 2269184                        0.0                       0.0  ...  40.761857
# 2269185                        0.0                       0.0  ...  40.752190
# 2269186                        2.0                       0.0  ...  40.760993
#
#          longitude                                           location  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2       -73.970024  {'latitude': 40.62179, 'longitude': -73.970024...
# 3              NaN                                                NaN
# 4              NaN                                                NaN
# ...            ...                                                ...
# 2269182 -73.955491  {'latitude': 40.620949, 'longitude': -73.9554915}
# 2269183        NaN                                                NaN
# 2269184 -73.963425  {'latitude': 40.7618573, 'longitude': -73.9634...
# 2269185 -73.993464  {'latitude': 40.7521904, 'longitude': -73.9934...
# 2269186 -73.990759  {'latitude': 40.7609926, 'longitude': -73.990759}
#
#          contributing_factor_vehicle_3  vehicle_type_code_3  \
# 0                                  NaN                  NaN
# 1                                  NaN                  NaN
# 2                          Unspecified                Sedan
# 3                                  NaN                  NaN
# 4                                  NaN                  NaN
# ...                                ...                  ...
# 2269182                            NaN                  NaN
# 2269183                            NaN                  NaN
# 2269184                            NaN                  NaN
# 2269185                            NaN                  NaN
# 2269186                            NaN                  NaN
#
#          cross_street_name contributing_factor_vehicle_4 vehicle_type_code_4  \
# 0                      NaN                           NaN                 NaN
# 1                      NaN                           NaN                 NaN
# 2                      NaN                           NaN                 NaN
# 3                      NaN                           NaN                 NaN
# 4                      NaN                           NaN                 NaN
# ...                    ...                           ...                 ...
# 2269182                NaN                           NaN                 NaN
# 2269183                NaN                           NaN                 NaN
# 2269184                NaN                           NaN                 NaN
# 2269185                NaN                           NaN                 NaN
# 2269186                NaN                           NaN                 NaN
#
#          contributing_factor_vehicle_5 vehicle_type_code_5
# 0                                  NaN                 NaN
# 1                                  NaN                 NaN
# 2                                  NaN                 NaN
# 3                                  NaN                 NaN
# 4                                  NaN                 NaN
# ...                                ...                 ...
# 2269182                            NaN                 NaN
# 2269183                            NaN                 NaN
# 2269184                            NaN                 NaN
# 2269185                            NaN                 NaN
# 2269186                            NaN                 NaN
#
# [2269187 rows x 33 columns]

# %%
df.dtypes
# Out:
# :id                                              str
# :version                                         str
# :created_at                      datetime64[us, UTC]
# :updated_at                      datetime64[us, UTC]
# crash_date                                       str
# crash_time                            datetime64[us]
# on_street_name                                   str
# off_street_name                                  str
# number_of_persons_injured                    float64
# number_of_persons_killed                     float64
# number_of_pedestrians_injured                  int64
# number_of_pedestrians_killed                   int64
# number_of_cyclist_injured                      int64
# number_of_cyclist_killed                       int64
# number_of_motorist_injured                     int64
# number_of_motorist_killed                      int64
# contributing_factor_vehicle_1                    str
# contributing_factor_vehicle_2                    str
# collision_id                                   int64
# vehicle_type_code1                               str
# vehicle_type_code2                               str
# borough                                          str
# zip_code                                         str
# latitude                                     float64
# longitude                                    float64
# location                                      object
# contributing_factor_vehicle_3                    str
# vehicle_type_code_3                              str
# cross_street_name                                str
# contributing_factor_vehicle_4                    str
# vehicle_type_code_4                              str
# contributing_factor_vehicle_5                    str
# vehicle_type_code_5                              str
# dtype: object

# %%
df = df.drop(columns=[':version', ':created_at',':updated_at',])

# %%
df.dtypes
# Out:
# :id                                         str
# crash_date                                  str
# crash_time                       datetime64[us]
# on_street_name                              str
# off_street_name                             str
# number_of_persons_injured               float64
# number_of_persons_killed                float64
# number_of_pedestrians_injured             int64
# number_of_pedestrians_killed              int64
# number_of_cyclist_injured                 int64
# number_of_cyclist_killed                  int64
# number_of_motorist_injured                int64
# number_of_motorist_killed                 int64
# contributing_factor_vehicle_1               str
# contributing_factor_vehicle_2               str
# collision_id                              int64
# vehicle_type_code1                          str
# vehicle_type_code2                          str
# borough                                     str
# zip_code                                    str
# latitude                                float64
# longitude                               float64
# location                                 object
# contributing_factor_vehicle_3               str
# vehicle_type_code_3                         str
# cross_street_name                           str
# contributing_factor_vehicle_4               str
# vehicle_type_code_4                         str
# contributing_factor_vehicle_5               str
# vehicle_type_code_5                         str
# dtype: object

# %%
df["crash_date"] = pd.to_datetime(df["crash_date"])

# %%
df['crash_time'] = pd.to_datetime(df['crash_time'], format="%H:%M")

# %% [markdown]
# df.pivot_table(index='Row_Column', columns='Column_Header', values='Data_Column', aggfunc='mean')

# %%
collision_table = pd.pivot_table(
    data = df,
    index = 'contributing_factor_vehicle_1',
    aggfunc = 'mean',
    values = ['number_of_persons_injured', 'number_of_persons_killed']
).sort_values('number_of_persons_killed',ascending=False)

# %%
collision_table.head(20)
# Out:
#                                                     number_of_persons_injured  \
# contributing_factor_vehicle_1
# Illnes                                                               0.924152
# Tinted Windows                                                       0.557604
# Unsafe Speed                                                         0.702688
# Drugs (illegal)                                                      0.731855
# Pedestrian/Bicyclist/Other Pedestrian Error/Con...                   0.810217
# Traffic Control Disregarded                                          0.732851
# Drugs (Illegal)                                                      0.482100
# Passenger Distraction                                                0.536937
# Other Lighting Defects                                               0.561321
# Alcohol Involvement                                                  0.499755
# Pavement Defective                                                   0.410420
# Tow Hitch Defective                                                  0.141129
# Driverless/Runaway Vehicle                                           0.231135
# Physical Disability                                                  0.625543
# Lost Consciousness                                                   0.200105
# Failure to Yield Right-of-Way                                        0.545029
# Aggressive Driving/Road Rage                                         0.469785
# Driver Inexperience                                                  0.336032
# Fell Asleep                                                          0.484457
# Failure to Keep Right                                                0.339731
#
#                                                     number_of_persons_killed
# contributing_factor_vehicle_1
# Illnes                                                              0.029604
# Tinted Windows                                                      0.013953
# Unsafe Speed                                                        0.013184
# Drugs (illegal)                                                     0.009100
# Pedestrian/Bicyclist/Other Pedestrian Error/Con...                  0.008903
# Traffic Control Disregarded                                         0.007363
# Drugs (Illegal)                                                     0.007160
# Passenger Distraction                                               0.005552
# Other Lighting Defects                                              0.004739
# Alcohol Involvement                                                 0.004446
# Pavement Defective                                                  0.004132
# Tow Hitch Defective                                                 0.004065
# Driverless/Runaway Vehicle                                          0.003413
# Physical Disability                                                 0.003389
# Lost Consciousness                                                  0.002968
# Failure to Yield Right-of-Way                                       0.002310
# Aggressive Driving/Road Rage                                        0.002101
# Driver Inexperience                                                 0.002018
# Fell Asleep                                                         0.001856
# Failure to Keep Right                                               0.001723

# %%
# sns.countplot(collision_table ,x='number_of_persons_injured')

# %%
df['injuries'] = (df['number_of_persons_injured']>0)
df['deaths'] = (df['number_of_persons_killed']>0)

df['injuries']
# Out:
# 0           True
# 1           True
# 2           True
# 3          False
# 4          False
#            ...
# 2269182    False
# 2269183    False
# 2269184    False
# 2269185    False
# 2269186     True
# Name: injuries, Length: 2269187, dtype: bool

# %%
df['crash_date'] = pd.to_datetime(df['crash_date'])

# %%
caused_death = df[ df['deaths'] == True ]
no_deaths = df[ df['deaths'] == False ]

# %%
caused_death
# Out:
#                         :id crash_date          crash_time  \
# 50       row-2c4h~58fy-stgf 2021-07-09 2026-07-14 00:43:00
# 159      row-qgnf-bi5i_4hjf 2021-12-12 2026-07-14 09:09:00
# 602      row-y7bz-ew7s~ykby 2021-04-15 2026-07-14 15:18:00
# 616      row-ycwz~genf.dgx8 2021-04-15 2026-07-14 22:36:00
# 1332     row-viwf.kmj2_s8zk 2021-04-17 2026-07-14 13:31:00
# ...                     ...        ...                 ...
# 2262645  row-bhjr-wdwj.6xus 2021-05-02 2026-07-14 21:39:00
# 2262905  row-k6vv_xefr_tewc 2013-04-09 2026-07-14 20:28:00
# 2266956  row-n7a4~gx92-sr95 2013-02-21 2026-07-14 20:10:00
# 2267676  row-xepe~s8p6.vt86 2013-02-23 2026-07-14 14:40:00
# 2268958  row-gun3_npsi.wzkf 2013-03-11 2026-07-14 19:50:00
#
#                            on_street_name                   off_street_name  \
# 50                           ELIOT AVENUE                               NaN
# 159                         JEROME AVENUE                               NaN
# 602                              4 AVENUE                      FOREST PLACE
# 616           Trans- Manhattan Expressway                  Amsterdam Avenue
# 1332                     AMSTERDAM AVENUE                               NaN
# ...                                   ...                               ...
# 2262645                   HYLAN BOULEVARD                       TYSENS LANE
# 2262905  KINGS HIGHWAY                     CLARENDON ROAD
# 2266956  BAISLEY BOULEVARD                 166 STREET
# 2267676  REMSEN AVENUE                     AVENUE J
# 2268958  SOUNDVIEW AVENUE                  TAYLOR AVENUE
#
#          number_of_persons_injured  number_of_persons_killed  \
# 50                             0.0                       1.0
# 159                            0.0                       1.0
# 602                            0.0                       1.0
# 616                            4.0                       1.0
# 1332                           0.0                       1.0
# ...                            ...                       ...
# 2262645                        0.0                       1.0
# 2262905                        0.0                       1.0
# 2266956                        0.0                       1.0
# 2267676                        2.0                       1.0
# 2268958                        0.0                       1.0
#
#          number_of_pedestrians_injured  number_of_pedestrians_killed  \
# 50                                   0                             1
# 159                                  0                             1
# 602                                  0                             1
# 616                                  0                             0
# 1332                                 0                             1
# ...                                ...                           ...
# 2262645                              0                             1
# 2262905                              0                             0
# 2266956                              0                             0
# 2267676                              0                             0
# 2268958                              0                             1
#
#          number_of_cyclist_injured  ...  \
# 50                               0  ...
# 159                              0  ...
# 602                              0  ...
# 616                              0  ...
# 1332                             0  ...
# ...                            ...  ...
# 2262645                          0  ...
# 2262905                          0  ...
# 2266956                          0  ...
# 2267676                          0  ...
# 2268958                          0  ...
#
#                                                   location  \
# 50       {'latitude': 40.720535, 'longitude': -73.88885...
# 159      {'latitude': 40.84036, 'longitude': -73.91807,...
# 602      {'latitude': 40.620487, 'longitude': -74.02930...
# 616                                                    NaN
# 1332     {'latitude': 40.782463, 'longitude': -73.97883...
# ...                                                    ...
# 2262645  {'latitude': 40.563915, 'longitude': -74.11637...
# 2262905                                                NaN
# 2266956  {'latitude': 40.6796533, 'longitude': -73.7772...
# 2267676  {'latitude': 40.6385777, 'longitude': -73.9041...
# 2268958  {'latitude': 40.8175206, 'longitude': -73.8620...
#
#          contributing_factor_vehicle_3  vehicle_type_code_3 cross_street_name  \
# 50                                 NaN                  NaN               NaN
# 159                                NaN                  NaN               NaN
# 602                                NaN                  NaN               NaN
# 616                                NaN                  NaN               NaN
# 1332                               NaN                  NaN               NaN
# ...                                ...                  ...               ...
# 2262645                            NaN                  NaN               NaN
# 2262905                            NaN                  NaN               NaN
# 2266956                            NaN                  NaN               NaN
# 2267676                            NaN                  NaN               NaN
# 2268958                            NaN                  NaN               NaN
#
#         contributing_factor_vehicle_4  vehicle_type_code_4  \
# 50                                NaN                  NaN
# 159                               NaN                  NaN
# 602                               NaN                  NaN
# 616                               NaN                  NaN
# 1332                              NaN                  NaN
# ...                               ...                  ...
# 2262645                           NaN                  NaN
# 2262905                           NaN                  NaN
# 2266956                           NaN                  NaN
# 2267676                           NaN                  NaN
# 2268958                           NaN                  NaN
#
#         contributing_factor_vehicle_5 vehicle_type_code_5 injuries deaths
# 50                                NaN                 NaN    False   True
# 159                               NaN                 NaN    False   True
# 602                               NaN                 NaN    False   True
# 616                               NaN                 NaN     True   True
# 1332                              NaN                 NaN    False   True
# ...                               ...                 ...      ...    ...
# 2262645                           NaN                 NaN    False   True
# 2262905                           NaN                 NaN    False   True
# 2266956                           NaN                 NaN    False   True
# 2267676                           NaN                 NaN     True   True
# 2268958                           NaN                 NaN    False   True
#
# [3469 rows x 32 columns]

# %%
caused_injuries = df[ df['injuries'] == True ]
no_injuries = df[ df['injuries'] == False ]

# %%
caused_death['crash_date'].hist(bins=48,figsize=(20,10), density=True,alpha=0.5, color='red')
no_deaths['crash_date'].hist(bins=48,figsize=(20,10), density=True,alpha=0.5, color='blue')
# Out:
# <Axes: >

# %%
# caused_death['crash_date'].hist(bins=48,figsize=(20,10), density=True,alpha=0.5, color='red')
# no_deaths['crash_date'].hist(bins=48,figsize=(20,10), density=True,alpha=0.5, color='green')

# caused_death['crash_date'].hist(
#     bins=48, 
#     figsize=(20,10),  
#     density=True, 
#     alpha=0.5,  
#     color='red' 
# )

# no_deaths['crash_date'].hist(
#     bins=48,
#     figsize=(20,10),
#     density=True,
#     alpha=0.5,
#     color='blue'
# )

# %%
caused_death['crash_time'].hist(
    bins=24, 
    figsize=(20,10),  
    density=True, 
    alpha=0.5,  
    color='red' 
)

no_deaths['crash_time'].hist(
    bins=24,
    figsize=(20,10),
    density=True,
    alpha=0.5,
    color='blue'
)
# Out:
# <Axes: >

# %%
caused_death['crash_date'].isna().sum()
caused_death.shape
# Out:
# (3469, 32)

# %%
df['crash_date'].head()
# Out:
# 0   2021-09-11
# 1   2022-03-26
# 2   2023-11-01
# 3   2022-06-29
# 4   2022-09-21
# Name: crash_date, dtype: datetime64[us]

# %%
df.dtypes
# Out:
# :id                                         str
# crash_date                       datetime64[us]
# crash_time                       datetime64[us]
# on_street_name                              str
# off_street_name                             str
# number_of_persons_injured               float64
# number_of_persons_killed                float64
# number_of_pedestrians_injured             int64
# number_of_pedestrians_killed              int64
# number_of_cyclist_injured                 int64
# number_of_cyclist_killed                  int64
# number_of_motorist_injured                int64
# number_of_motorist_killed                 int64
# contributing_factor_vehicle_1               str
# contributing_factor_vehicle_2               str
# collision_id                              int64
# vehicle_type_code1                          str
# vehicle_type_code2                          str
# borough                                     str
# zip_code                                    str
# latitude                                float64
# longitude                               float64
# location                                 object
# contributing_factor_vehicle_3               str
# vehicle_type_code_3                         str
# cross_street_name                           str
# contributing_factor_vehicle_4               str
# vehicle_type_code_4                         str
# contributing_factor_vehicle_5               str
# vehicle_type_code_5                         str
# injuries                                   bool
# deaths                                     bool
# dtype: object

# %%
df_cord = df[((df["latitude"] > 40 )& (df["latitude"] < 41 ))&( (df["longitude"] > -74.5) & (df["longitude"] < -74))].sample(1000)
# df_cord = df["latitude"] > 40
df_cord
# Out:
#                         :id crash_date          crash_time  \
# 937093   row-xmri_a5kv.4phe 2017-11-15 2026-07-14 13:50:00
# 910847   row-rh75.399e-yyzy 2017-12-20 2026-07-14 07:00:00
# 471299   row-js8v~744v.aibs 2019-12-30 2026-07-14 15:15:00
# 1219944  row-xczc.k3fy_daip 2016-09-04 2026-07-14 18:25:00
# 462869   row-6dac_w3pp-aj58 2019-12-23 2026-07-14 19:45:00
# ...                     ...        ...                 ...
# 1483712  row-555k_3yxe~fwcz 2015-06-24 2026-07-14 15:00:00
# 1182313  row-bwyz.chdr.fiv5 2016-10-21 2026-07-14 15:15:00
# 1698263  row-hxh2~9vqm_rufs 2014-06-09 2026-07-14 23:48:00
# 984887   row-62w4-kpmm_34ib 2017-09-01 2026-07-14 08:40:00
# 566688   row-i2fz.m3sr-mj9w 2019-07-15 2026-07-14 10:15:00
#
#                            on_street_name                   off_street_name  \
# 937093   FOREST HILL ROAD                                   RICHMOND AVENUE
# 910847   40 STREET                                                 5 AVENUE
# 471299   FOREST AVENUE                                      RICHMOND AVENUE
# 1219944                               NaN                               NaN
# 462869   74 STREET                                    FORT HAMILTON PARKWAY
# ...                                   ...                               ...
# 1483712  ROBINSON AVENUE                   SYCAMORE STREET
# 1182313  CLINTON AVENUE                                    HENDERSON AVENUE
# 1698263  5 AVENUE                          OVINGTON AVENUE
# 984887   SAINT JOHNS AVENUE                                     DAYNA DRIVE
# 566688   65 STREET                                                 6 AVENUE
#
#          number_of_persons_injured  number_of_persons_killed  \
# 937093                         0.0                       0.0
# 910847                         0.0                       0.0
# 471299                         1.0                       0.0
# 1219944                        0.0                       0.0
# 462869                         1.0                       0.0
# ...                            ...                       ...
# 1483712                        0.0                       0.0
# 1182313                        0.0                       0.0
# 1698263                        1.0                       0.0
# 984887                         0.0                       0.0
# 566688                         0.0                       0.0
#
#          number_of_pedestrians_injured  number_of_pedestrians_killed  \
# 937093                               0                             0
# 910847                               0                             0
# 471299                               0                             0
# 1219944                              0                             0
# 462869                               0                             0
# ...                                ...                           ...
# 1483712                              0                             0
# 1182313                              0                             0
# 1698263                              0                             0
# 984887                               0                             0
# 566688                               0                             0
#
#          number_of_cyclist_injured  ...  \
# 937093                           0  ...
# 910847                           0  ...
# 471299                           0  ...
# 1219944                          0  ...
# 462869                           0  ...
# ...                            ...  ...
# 1483712                          0  ...
# 1182313                          0  ...
# 1698263                          0  ...
# 984887                           0  ...
# 566688                           0  ...
#
#                                                   location  \
# 937093     {'latitude': 40.570877, 'longitude': -74.16984}
# 910847     {'latitude': 40.650703, 'longitude': -74.00449}
# 471299    {'latitude': 40.624958, 'longitude': -74.145775}
# 1219944   {'latitude': 40.568512, 'longitude': -74.092415}
# 462869     {'latitude': 40.626293, 'longitude': -74.01572}
# ...                                                    ...
# 1483712  {'latitude': 40.5424924, 'longitude': -74.1565...
# 1182313   {'latitude': 40.640358, 'longitude': -74.097885}
# 1698263  {'latitude': 40.6325799, 'longitude': -74.0213...
# 984887     {'latitude': 40.610073, 'longitude': -74.06908}
# 566688       {'latitude': 40.63552, 'longitude': -74.0167}
#
#          contributing_factor_vehicle_3  vehicle_type_code_3  \
# 937093                             NaN                  NaN
# 910847                             NaN                  NaN
# 471299                             NaN                  NaN
# 1219944                            NaN                  NaN
# 462869                             NaN                  NaN
# ...                                ...                  ...
# 1483712                            NaN                  NaN
# 1182313                            NaN                  NaN
# 1698263                            NaN                  NaN
# 984887                             NaN                  NaN
# 566688                             NaN                  NaN
#
#                                 cross_street_name  \
# 937093                                        NaN
# 910847                                        NaN
# 471299                                        NaN
# 1219944  1215      CAPODANNO BOULEVARD
# 462869                                        NaN
# ...                                           ...
# 1483712                                       NaN
# 1182313                                       NaN
# 1698263                                       NaN
# 984887                                        NaN
# 566688                                        NaN
#
#         contributing_factor_vehicle_4  vehicle_type_code_4  \
# 937093                            NaN                  NaN
# 910847                            NaN                  NaN
# 471299                            NaN                  NaN
# 1219944                           NaN                  NaN
# 462869                            NaN                  NaN
# ...                               ...                  ...
# 1483712                           NaN                  NaN
# 1182313                           NaN                  NaN
# 1698263                           NaN                  NaN
# 984887                            NaN                  NaN
# 566688                            NaN                  NaN
#
#         contributing_factor_vehicle_5 vehicle_type_code_5 injuries deaths
# 937093                            NaN                 NaN    False  False
# 910847                            NaN                 NaN    False  False
# 471299                            NaN                 NaN     True  False
# 1219944                           NaN                 NaN    False  False
# 462869                            NaN                 NaN     True  False
# ...                               ...                 ...      ...    ...
# 1483712                           NaN                 NaN    False  False
# 1182313                           NaN                 NaN    False  False
# 1698263                           NaN                 NaN     True  False
# 984887                            NaN                 NaN    False  False
# 566688                            NaN                 NaN    False  False
#
# [1000 rows x 32 columns]

# %%
plt.scatter(df_cord['latitude'], df_cord['longitude'], alpha=0.3)
# df_cord.show()

# %%
df.dtypes
# Out:
# :id                                         str
# crash_date                       datetime64[us]
# crash_time                       datetime64[us]
# on_street_name                              str
# off_street_name                             str
# number_of_persons_injured               float64
# number_of_persons_killed                float64
# number_of_pedestrians_injured             int64
# number_of_pedestrians_killed              int64
# number_of_cyclist_injured                 int64
# number_of_cyclist_killed                  int64
# number_of_motorist_injured                int64
# number_of_motorist_killed                 int64
# contributing_factor_vehicle_1               str
# contributing_factor_vehicle_2               str
# collision_id                              int64
# vehicle_type_code1                          str
# vehicle_type_code2                          str
# borough                                     str
# zip_code                                    str
# latitude                                float64
# longitude                               float64
# location                                 object
# contributing_factor_vehicle_3               str
# vehicle_type_code_3                         str
# cross_street_name                           str
# contributing_factor_vehicle_4               str
# vehicle_type_code_4                         str
# contributing_factor_vehicle_5               str
# vehicle_type_code_5                         str
# injuries                                   bool
# deaths                                     bool
# dtype: object

# %%
borough_table = pd.pivot_table(
    data = df,
    index = 'borough',
    aggfunc = 'mean',
    values = ['number_of_persons_injured' , 'number_of_persons_killed']
)

# %%
borough_table
# Out:
#                number_of_persons_injured  number_of_persons_killed
# borough
# BRONX                           0.352835                  0.001395
# BROOKLYN                        0.355762                  0.001467
# MANHATTAN                       0.232965                  0.001141
# QUEENS                          0.322711                  0.001443
# STATEN ISLAND                   0.304298                  0.001642

# %%
borough_table.plot(kind="bar")
# Out:
# <Axes: xlabel='borough'>

# %%
df['injured_peo'] = (df["number_of_persons_injured"] > 0).astype(int)
df['dead_peo'] = (df["number_of_persons_killed"] > 0).astype(int)

# %%
borough_df = (
    df.groupby("borough")[["injured_peo", "dead_peo"]]
      .sum()
)

borough_df.plot(kind="bar", width=0.7, logy=True)
# Out:
# <Axes: xlabel='borough'>
